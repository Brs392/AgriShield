# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D,
    Flatten, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from PIL import Image
import matplotlib.pyplot as plt

# %%
train_dir = r"C:\Users\KIIT\Desktop\MajorProject\AgriShield\data\processed\PlantVillageDataset\train_val_test\train"
val_dir   = r"C:\Users\KIIT\Desktop\MajorProject\AgriShield\data\processed\PlantVillageDataset\train_val_test\val"
test_dir  = r"C:\Users\KIIT\Desktop\MajorProject\AgriShield\data\processed\PlantVillageDataset\train_val_test\test"

# %%
IMG_SIZE = (128, 128)   # smaller = faster
BATCH_SIZE = 32
EPOCHS = 20
NUM_CLASSES = 15

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 14437 images belonging to 15 classes.
# Found 2073 images belonging to 15 classes.
# Found 4128 images belonging to 15 classes.

# %%
model = Sequential([

    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(256, activation='relu'),
    Dropout(0.5),

    Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 126, 126, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 61, 61, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       2,359,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 15)                  │           3,855 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,753,743 (10.50 MB)
#  Trainable params: 2,752,783 (10.50 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "cnn_plant_disease.keras",
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    steps_per_epoch=len(train_generator),
    validation_steps=len(val_generator),
    callbacks=[early_stopping, checkpoint]
)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3685 - loss: 2.6126
# C:\Users\KIIT\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_loss improved from inf to 3.74794, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 810s 2s/step - accuracy: 0.3687 - loss: 2.6111 - val_accuracy: 0.2610 - val_loss: 3.7479
# Epoch 2/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.5498 - loss: 1.4363
# Epoch 2: val_loss improved from 3.74794 to 2.03078, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 411s 908ms/step - accuracy: 0.5498 - loss: 1.4362 - val_accuracy: 0.4385 - val_loss: 2.0308
# Epoch 3/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.6035 - loss: 1.2490
# Epoch 3: val_loss did not improve from 2.03078
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 371s 820ms/step - accuracy: 0.6036 - loss: 1.2489 - val_accuracy: 0.4993 - val_loss: 2.3306
# Epoch 4/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.6504 - loss: 1.0760
# Epoch 4: val_loss improved from 2.03078 to 1.95233, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 373s 824ms/step - accuracy: 0.6504 - loss: 1.0760 - val_accuracy: 0.5007 - val_loss: 1.9523
# Epoch 5/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.6871 - loss: 0.9589
# Epoch 5: val_loss did not improve from 1.95233
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 369s 816ms/step - accuracy: 0.6871 - loss: 0.9588 - val_accuracy: 0.5885 - val_loss: 2.7823
# Epoch 6/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 789ms/step - accuracy: 0.7419 - loss: 0.8073
# Epoch 6: val_loss did not improve from 1.95233
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 370s 819ms/step - accuracy: 0.7419 - loss: 0.8072 - val_accuracy: 0.5620 - val_loss: 2.2205
# Epoch 7/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - accuracy: 0.7770 - loss: 0.6958
# Epoch 7: val_loss did not improve from 1.95233
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 369s 815ms/step - accuracy: 0.7770 - loss: 0.6958 - val_accuracy: 0.6261 - val_loss: 2.7331
# Epoch 8/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 780ms/step - accuracy: 0.7924 - loss: 0.6628
# Epoch 8: val_loss improved from 1.95233 to 1.37339, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 365s 807ms/step - accuracy: 0.7924 - loss: 0.6627 - val_accuracy: 0.7255 - val_loss: 1.3734
# Epoch 9/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.8146 - loss: 0.5803
# Epoch 9: val_loss improved from 1.37339 to 0.93879, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 397s 878ms/step - accuracy: 0.8146 - loss: 0.5802 - val_accuracy: 0.7733 - val_loss: 0.9388
# Epoch 10/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.8356 - loss: 0.5167
# Epoch 10: val_loss did not improve from 0.93879
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 383s 847ms/step - accuracy: 0.8356 - loss: 0.5167 - val_accuracy: 0.6184 - val_loss: 1.6978
# Epoch 11/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.8495 - loss: 0.4673
# Epoch 11: val_loss did not improve from 0.93879
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 442s 977ms/step - accuracy: 0.8495 - loss: 0.4673 - val_accuracy: 0.7453 - val_loss: 1.0110
# Epoch 12/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.8583 - loss: 0.4503
# Epoch 12: val_loss improved from 0.93879 to 0.59177, saving model to cnn_plant_disease.keras
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 356s 787ms/step - accuracy: 0.8583 - loss: 0.4503 - val_accuracy: 0.8384 - val_loss: 0.5918
# Epoch 13/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.8720 - loss: 0.4114
# Epoch 13: val_loss did not improve from 0.59177
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 357s 790ms/step - accuracy: 0.8720 - loss: 0.4114 - val_accuracy: 0.7202 - val_loss: 1.4366
# Epoch 14/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - accuracy: 0.8762 - loss: 0.4002
# Epoch 14: val_loss did not improve from 0.59177
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 339s 750ms/step - accuracy: 0.8762 - loss: 0.4002 - val_accuracy: 0.6778 - val_loss: 2.4851
# Epoch 15/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.8866 - loss: 0.3721
# Epoch 15: val_loss did not improve from 0.59177
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 328s 725ms/step - accuracy: 0.8866 - loss: 0.3721 - val_accuracy: 0.8302 - val_loss: 0.6430
# Epoch 16/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.8916 - loss: 0.3579
# Epoch 16: val_loss did not improve from 0.59177
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 388s 858ms/step - accuracy: 0.8916 - loss: 0.3579 - val_accuracy: 0.7308 - val_loss: 1.3659
# Epoch 17/20
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.9036 - loss: 0.3172
# Epoch 17: val_loss did not improve from 0.59177
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 377s 835ms/step - accuracy: 0.9036 - loss: 0.3173 - val_accuracy: 0.5953 - val_loss: 1.9378

# %%
model.save("final_cnn_plant_disease.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.8919 - loss: 0.4467
# Test Accuracy: 0.8454
